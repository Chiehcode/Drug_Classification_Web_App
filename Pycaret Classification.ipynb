# %%
import numpy as np 
import pandas as pd
from pycaret.classification import *

# %%
train = pd.read_csv('C:\桌面\Python\PyCaret & Streamlit\Drug Classification\Data\Train.csv')
test  = pd.read_csv('C:\桌面\Python\PyCaret & Streamlit\Drug Classification\Data\Test.csv')

# %%
train.head()
# Out:
#    Age Sex Blood Pressure Cholesterol  Sodium to Potassium Ratio   Drug
# 0   23   F           HIGH        HIGH                     25.355  DrugY
# 1   47   M            LOW        HIGH                     13.093  drugC
# 2   47   M            LOW        HIGH                     10.114  drugC
# 3   28   F         NORMAL        HIGH                      7.798  drugX
# 4   61   F            LOW        HIGH                     18.043  DrugY

# %%
clf = setup(data = train, target = 'Drug')
# Out:
# <style  type="text/css" >
# </style><table id="T_dcb36764_31f3_11eb_a432_dcfb483670f8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dcb36764_31f3_11eb_a432_dcfb483670f8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dcb36764_31f3_11eb_a432_dcfb483670f8row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_dcb36764_31f3_11eb_a432_dcfb483670f8row0_col1" class="data row0 col1" >884</td>
#             </tr>
#             <tr>
#                         <th id="T_dcb36764_31f3_11eb_a432_dcfb483670f8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dcb36764_31f3_11eb_a432_dcfb483670f8row1_col0" class="data row1 col0" >Target</td>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_f9e6c45a_31f3_11eb_97a4_dcfb483670f8 th {
#           text-align: left;
# ...

# %%
dt = create_model('dt')
# Out:
# <style  type="text/css" >
# #T_03ceedae_31f4_11eb_8d6c_dcfb483670f8row10_col0,#T_03ceedae_31f4_11eb_8d6c_dcfb483670f8row10_col1,#T_03ceedae_31f4_11eb_8d6c_dcfb483670f8row10_col2,#T_03ceedae_31f4_11eb_8d6c_dcfb483670f8row10_col3,#T_03ceedae_31f4_11eb_8d6c_dcfb483670f8row10_col4,#T_03ceedae_31f4_11eb_8d6c_dcfb483670f8row10_col5,#T_03ceedae_31f4_11eb_8d6c_dcfb483670f8row10_col6{
#             background:  yellow;
#         }</style><table id="T_03ceedae_31f4_11eb_8d6c_dcfb483670f8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
bagged_dt = ensemble_model(dt, method = 'Bagging', n_estimators = 1000)
# Out:
# <style  type="text/css" >
# #T_0ceb0912_31f4_11eb_8bfe_dcfb483670f8row10_col0,#T_0ceb0912_31f4_11eb_8bfe_dcfb483670f8row10_col1,#T_0ceb0912_31f4_11eb_8bfe_dcfb483670f8row10_col2,#T_0ceb0912_31f4_11eb_8bfe_dcfb483670f8row10_col3,#T_0ceb0912_31f4_11eb_8bfe_dcfb483670f8row10_col4,#T_0ceb0912_31f4_11eb_8bfe_dcfb483670f8row10_col5,#T_0ceb0912_31f4_11eb_8bfe_dcfb483670f8row10_col6{
#             background:  yellow;
#         }</style><table id="T_0ceb0912_31f4_11eb_8bfe_dcfb483670f8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
tuned_dt = tune_model(bagged_dt)
# Out:
# <style  type="text/css" >
# #T_65e85bae_31f4_11eb_8f16_dcfb483670f8row10_col0,#T_65e85bae_31f4_11eb_8f16_dcfb483670f8row10_col1,#T_65e85bae_31f4_11eb_8f16_dcfb483670f8row10_col2,#T_65e85bae_31f4_11eb_8f16_dcfb483670f8row10_col3,#T_65e85bae_31f4_11eb_8f16_dcfb483670f8row10_col4,#T_65e85bae_31f4_11eb_8f16_dcfb483670f8row10_col5,#T_65e85bae_31f4_11eb_8f16_dcfb483670f8row10_col6{
#             background:  yellow;
#         }</style><table id="T_65e85bae_31f4_11eb_8f16_dcfb483670f8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
final_dt = finalize_model(tuned_dt)

# %%
save_model(final_dt,'Final Decision Tree Model')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='Drug',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strateg...
#                                                                           min_impurity_decrease=0.0,
# ...
